# %%
from zipline.api import attach_pipeline, pipeline_output, record
from zipline.pipeline import Pipeline, CustomFactor
from zipline.pipeline.factors import Returns, AverageDollarVolume
from zipline import run_algorithm
MONTH, YEAR = 21, 252
N_LONGS = N_SHORTS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c3c29c71d26f> in <module>
# ----> 1 from zipline.api import attach_pipeline, pipeline_output, record
#       2 from zipline.pipeline import Pipeline, CustomFactor
#       3 from zipline.pipeline.factors import Returns, AverageDollarVolume
#       4 from zipline import run_algorithm
#       5 MONTH, YEAR = 21, 252
#
# ~/.local/lib/python3.6/site-packages/zipline/__init__.py in <module>
#      19 # This is *not* a place to dump arbitrary classes/modules for convenience,
#      20 # it is a place to expose the public interfaces.
# ---> 21 from trading_calendars import get_calendar
#      22
#      23 from . import data
#
# ~/.local/lib/python3.6/site-packages/trading_calendars/__init__.py in <module>
#      14 # limitations under the License.
#      15
# ---> 16 from .trading_calendar import TradingCalendar
#      17 from .calendar_utils import (
#      18     clear_calendars,
#
# ~/.local/lib/python3.6/site-packages/trading_calendars/trading_calendar.py in <module>
#      17
#      18 from operator import attrgetter
# ---> 19 from pandas.tseries.holiday import AbstractHolidayCalendar
#      20 from six import with_metaclass
#      21 from pytz import UTC
#
# ~/.local/lib/python3.6/site-packages/pandas/__init__.py in <module>
#      40 import pandas.core.config_init
#      41
# ---> 42 from pandas.core.api import *
#      43 from pandas.core.sparse.api import *
#      44 from pandas.stats.api import *
#
# ~/.local/lib/python3.6/site-packages/pandas/core/api.py in <module>
#       8 from pandas.core.dtypes.missing import isna, isnull, notna, notnull
#       9 from pandas.core.categorical import Categorical
# ---> 10 from pandas.core.groupby import Grouper
#      11 from pandas.io.formats.format import set_eng_float_format
#      12 from pandas.core.index import (Index, CategoricalIndex, Int64Index,
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import DataFrameGroupBy, NamedAgg, SeriesGroupBy
#       2 from pandas.core.groupby.groupby import GroupBy
#       3 from pandas.core.groupby.grouper import Grouper
#       4
#       5 __all__ = [
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/generic.py in <module>
#      34 from pandas.util._decorators import Appender, Substitution
#      35
# ---> 36 from pandas.core.dtypes.cast import (
#      37     maybe_convert_objects,
#      38     maybe_downcast_numeric,
#
# ImportError: cannot import name 'maybe_downcast_numeric'
