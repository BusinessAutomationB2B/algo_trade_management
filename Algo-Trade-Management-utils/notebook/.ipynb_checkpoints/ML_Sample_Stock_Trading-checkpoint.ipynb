# %% [markdown]
# # Machine Learning and Trading
#
# https://www.quora.com/How-effective-is-machine-learning-in-trading

# %% [markdown]
# # First a different opinion (Negative)
#
# - Disclaimer: I don’t claim to be an expert in ML trading. What you will read is a set of views I have formed while personally investigating about the subject.
#
# - One special case of algo trading are High Frequency Trading firms. They mainly maximise not algorithmic efficiency, but speed of trading. They find very simple strategies and try to execute them in a millisecond time frame. That involves implementing trading algorithms in C++ or even FPGAs. From what I hear, the most complicated ML model they will use is Logistic Regression, not so complex if you ask me, but apparently it does the job.
#
# - In the more general scenario I’ll presume you’re referring to predicting stock prices based on historic data. There is a big buzz around it, lots of tutorials training LSTMs and showing 99% accuracy. Most of them ultimately fail to provide a reasonable testing strategy that actually measures financial gains / losses rather than algorithmic accuracy.
#
# - In my opinion, predicting stock prices using historical data is like trying to drive your car looking at the rear view mirror. Nothing guarantees that there is enough information in how past prices fluctuated that will help you predict the future.

# %% [markdown]
# # Now a Positive Opinion and Demo
# - Ishan Shah, Associate at Quantra
#     - Machine learning is an evolving field and the effectiveness of machine learning in all sort of fields including trading is going to increase.
#
#     - To demonstrate the effectiveness of the machine learning algorithm, I have written a simple support vector classifier model on S&P500 data which generated a return of 15%+. To see the implementation of XGBoost on US tech stocks read here

# %% [markdown]
# # Strategy
#
# - A set of training data is provided to the machine learning classification algorithm, each belonging to one of the categories.
#     - For instance, the categories can be to either buy or sell a stock. The classification algorithm builds a model based on the training data and then, classifies the test data into one of the categories.

# %%
# %%html
# <b> Ensure this is a code cell and use this html magic!</b>
# # <img src="/home/tester/GitHub/AlgoTrading/notebook/SVM_Fig.jpeg",width=60,height=60>
# <img src="SVM_Fig.jpeg",width=60,height=60>
# Out:
# <b> Ensure this is a code cell and use this html magic!</b>
# # <img src="/home/tester/GitHub/AlgoTrading/notebook/SVM_Fig.jpeg",width=60,height=60>
# <img src="SVM_Fig.jpeg",width=60,height=60>

# %% [markdown]
# # Step 1: Import the libraries
#
# In this step, we will import the necessary libraries that will be needed to create the strategy.

# %%
# Machine learning classification libraries
from sklearn.svm import SVC
from sklearn.metrics import scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix  # James added
 
# For data manipulation
import pandas as pd
import numpy as np
 
# To plot
import matplotlib.pyplot as plt
import seaborn
 
# To fetch data
from pandas_datareader import data as pdr

# time and date tools
import time
from datetime import datetime

# %% [markdown]
# # Step 2: Fetch data
#
# We will download the S&P500 data from google finance using pandas_datareader.
#
# After that, we will drop the missing values from the data and plot the S&P500 close price series.

# %%
# original article code - does not work
# Df = pdr.get_data_google('SPY', start="2012-01-01", end="2017-10-01")  

tickerList = ['SPY','APPL']

for ticker in tickerList:
    df = pdr.get_data_yahoo(ticker, start=datetime(2012,1,1), end=datetime(2017,10,1))
    file_path = '/home/tester/GitHub/AlgoTrading/notebook/'
    df.to_csv( file_path + ticker + '.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-64ee7ea86207> in <module>
#       5
#       6 for ticker in tickerList:
# ...

# %%
# read the marked up file
# ticker = 'SPY'  # original demo
ticker = "VHY.AX"
file_path = '/home/tester/GitHub/AlgoTrading/notebook/'
# for ticker in tickerList:
Df = pd.read_csv( file_path + ticker + '.csv', index_col=None, encoding = "ISO-8859-1", engine='python')  # create a pandas df 

Df= Df.dropna()
Df.Close.plot(figsize=(10,5))
plt.ylabel("S&P500 Price")
plt.show()

# %% [markdown]
# # Step 3: Determine the target variable
#
# - The target variable is the variable which the machine learning classification algorithm will predict. In this example, the target variable is whether S&P500 price will close up or close down on the next trading day.
#
# - We will first determine the actual trading signal using the following logic – if next trading day’s close price is greater than today’s close price then, we will buy the S&P500 index, else we will sell the S&P500 index. We will store +1 for the buy signal and -1 for the sell signal.

# %%
# Df['Close'].shift(-1) is tomorrow

y = np.where(Df['Close'].shift(-1) > Df['Close'],1,-1)

# %%
y
# Out:
# array([ 1,  1,  1, ...,  1, -1, -1])

# %% [markdown]
# # Step 4: Creation of predictors variables
#
# - The X is a dataset that holds the predictor’s variables which are used to predict target variable, ‘y’. The X consists of variables such as ‘Open – Close’ and ‘High – Low’. These can be understood as indicators based on which the algorithm will predict the option price.

# %%
Df['Open-Close'] = Df.Open - Df.Close
Df['High-Low'] = Df.High - Df.Low
Df['High-Close'] = Df.High - Df.Close   # James added
Df['Low-Close'] = Df.Low - Df.Close     # James added
# reference from turtle trading system
# 5 day high
# Df['HH'] = Df.High.shift(1).rolling(window=3).max()  
# 5-days low  
# Df['LL'] = Df.Low.shift(1).rolling(window=3).min()  
 # X=Df[['Open-Close','High-Low','HH','LL']]

X=Df[['Open-Close','High-Low', 'High-Close', 'Low-Close']]

Df= Df.dropna()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# X.fillna(method='ffill')
# X.fillna(0)
# Df.head()
X.head()
# Out:
#     Open-Close  High-Low  High-Close  Low-Close
# 42   -1.040001  1.139999    0.099998  -1.040001
# 43   -0.500000  0.500000    0.000000  -0.500000
# 44    0.000000  0.000000    0.000000   0.000000
# 45   -0.290001  0.290001    0.000000  -0.290001
# 46   -0.080002  0.250000    0.000000  -0.250000

# %% [markdown]
# - In the later part of the code, the machine learning classification algorithm will use the predictors and target variable in the training phase to create the model and then, predict the target variable in the test dataset.

# %% [markdown]
# # Step 5: Test and train dataset split

# %% [markdown]
# In this step, we will split data into the train dataset and the test dataset.
#
# 1. First 80% of data is used for training and remaining data for testing
# 2. X_train and y_train are train dataset
# 3. X_test and y_test are test dataset

# %%
split_percentage = 0.8
split = int(split_percentage*len(Df))
 
# Train data set
X_train = X[:split]
y_train = y[:split]
 
# Test data set
X_test = X[split:]
y_test = y[split:]

# %%
split
# Out:
# 1721

# %%
X_train
# Out:
#       Open-Close  High-Low  High-Close  Low-Close
# 42     -1.040001  1.139999    0.099998  -1.040001
# 43     -0.500000  0.500000    0.000000  -0.500000
# 44      0.000000  0.000000    0.000000   0.000000
# 45     -0.290001  0.290001    0.000000  -0.290001
# 46     -0.080002  0.250000    0.000000  -0.250000
# ...          ...       ...         ...        ...
# 1758    0.320000  0.450001    0.450001   0.000000
# 1759   -0.230000  0.580002    0.070000  -0.510002
# 1760    0.210003  0.320004    0.320004   0.000000
# 1761   -0.220001  0.340000    0.029999  -0.310001
# 1762   -0.399998  0.530003    0.010002  -0.520000
#
# [1721 rows x 4 columns]

# %% [markdown]
# # Step 6: Create the machine learning classification model using the train dataset
#
# - We will create the machine learning classification model based on the train dataset. This model will be later used to predict the trading signal in the test dataset.

# %%
cls = SVC().fit(X_train, y_train)

# %%
cls
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# # Step 7: The classification model accuracy
#
# We will compute the accuracy of the classification model on the train and test dataset, by comparing the actual values of the trading signal with the predicted values of the trading signal. The function accuracy_score() will be used to calculate the accuracy.
#
# Syntax: accuracy_score(target_actual_value,target_predicted_value)
#
# 1. target_actual_value: correct signal values
# 2. target_predicted_value: predicted signal values

# %%
accuracy_train = accuracy_score(y_train, cls.predict(X_train))
 
accuracy_test = accuracy_score(y_test, cls.predict(X_test))
print('\nTrain Accuracy:{: .2f}%'.format(accuracy_train*100))
print('Test Accuracy:{: .2f}%'.format(accuracy_test*100))
# Out:
# Train Accuracy: 53.17%
# Test Accuracy: 53.83%

# %% [markdown]
# An accuracy of 50%+ in test data suggests that the classification model is effective.

# %% [markdown]
# # Step 8: Prediction
#
# We will predict the signal (buy or sell) for the test data set, using the cls.predict() function. Then, we will compute the strategy returns based on the signal predicted by the model in the test dataset. We save it in the column ‘Strategy_Return’ and then, plot the cumulative strategy returns.

# %%
# James: I realy loved this demo. It is so professional. Return figures are very important. Should be verified via event based simulation
Df['Predicted_Signal'] = cls.predict(X)
 
# Calculate log returns
Df['Return'] = np.log(Df.Close.shift(-1) / Df.Close)*100
Df['Strategy_Return'] = Df.Return * Df.Predicted_Signal
Df.Strategy_Return.iloc[split:].cumsum().plot(figsize=(10,5))
plt.ylabel("Strategy Returns (%)")
plt.show()

# %% [markdown]
# As seen from the graph, the machine learning classification strategy generates a return of around 15% in the test dataset.

# %%
X
