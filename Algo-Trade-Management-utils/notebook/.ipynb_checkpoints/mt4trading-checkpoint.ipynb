# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("mt4results.csv")

# %%
df.shape
# Out:
# (161, 14)

# %%
df
# Out:
#        Ticket            Open Time       Type           Size    Item    Price  \
# 0    27409852  2019.06.06 23:23:08    balance  BPAY Received     200      NaN
# 1    27460422  2019.06.11 01:35:02        buy           0.01  eurusd  1.13131
# 2    27465045  2019.06.11 03:15:06        buy           0.01  eurusd  1.13090
# 3    27467679  2019.06.11 05:56:20       sell           0.01  eurusd  1.13169
# 4    27468425  2019.06.11 07:15:00       sell           0.01  eurusd  1.13196
# ..        ...                  ...        ...            ...     ...      ...
# 156  30557266  2019.10.29 13:33:18        buy           0.01  audusd  0.68563
# 157  30559138  2019.10.29 14:33:59       sell           0.01  audusd  0.68579
# 158  30580913  2019.10.30 12:20:49        buy           0.01  audusd  0.68630
# 159  30614279  2019.10.31 12:00:57  buy limit           0.01  audusd  0.68065
# 160  30628264  2019.10.31 23:11:12        buy           0.01  audusd  0.68921
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Ticket            Open Time       Type           Size    Item    Price  \
# 0    27409852  2019.06.06 23:23:08    balance  BPAY Received     200      NaN
# 1    27460422  2019.06.11 01:35:02        buy           0.01  eurusd  1.13131
# 2    27465045  2019.06.11 03:15:06        buy           0.01  eurusd  1.13090
# 3    27467679  2019.06.11 05:56:20       sell           0.01  eurusd  1.13169
# 4    27468425  2019.06.11 07:15:00       sell           0.01  eurusd  1.13196
# ..        ...                  ...        ...            ...     ...      ...
# 156  30557266  2019.10.29 13:33:18        buy           0.01  audusd  0.68563
# 157  30559138  2019.10.29 14:33:59       sell           0.01  audusd  0.68579
# 158  30580913  2019.10.30 12:20:49        buy           0.01  audusd  0.68630
# 159  30614279  2019.10.31 12:00:57  buy limit           0.01  audusd  0.68065
# 160  30628264  2019.10.31 23:11:12        buy           0.01  audusd  0.68921
#
# ...

# %%
pnl=df['Profit']
pnl
# Out:
# 0       NaN
# 1      0.21
# 2      1.05
# 3     -0.45
# 4     -0.87
#        ...
# 156   -0.13
# 157   -0.85
# 158   -0.32
# 159     NaN
# 160    1.07
# Name: Profit, Length: 161, dtype: float64

# %%
pnl.describe()
# Out:
# count    143.000000
# mean      -0.392797
# std        2.527059
# min      -15.870000
# 25%       -0.730000
# 50%       -0.020000
# 75%        0.400000
# max        7.110000
# Name: Profit, dtype: float64

# %%
#plt.style.use('ggplot')
pnl.hist(bins=30)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-580a068a3548> in <module>
# ----> 1 dir(pd.hist)
#
# AttributeError: module 'pandas' has no attribute 'hist'
