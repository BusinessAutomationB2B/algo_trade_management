# %% [markdown]
# Event based tester - SentDex style 2013 (in SVN Repo)

# %%
# http://stackoverflow.com/questions/1557571/how-to-get-time-of-a-python-program-execution
# time execution


# -*- coding: utf-8 -*-
"""
Created on Sun Sep 29 18:10:50 2013

@author: chingl
"""

import time
from datetime import datetime
from time import mktime

start_time = time.time()

def backTest():


#Trade Rules:
#Buy every time you are not invested and stock price drops.
#sell every time the stock price is more than .2% higher than when you bought. (.002)

    investmentAmount = 50000
    tradeComm = 7

    stance = 'none'
    buyPrice = 0
    sellPrice = 0
    previousPrice = 0

    totalProfit = 0

    tradeCount = 0
    startingPrice = 0

    startingTime = 0
    endingTime = 0

    totalInvestedTime = 0

    overallStartingTime = 0
    overallEndingTime = 0

    bigDataFile = open('AMAT.txt','r')
    readFile = bigDataFile.read()
    lineSplit = readFile.split('\n')

    for everyLine in lineSplit:
    
        dividedLine = everyLine.split(',')
        stockName = dividedLine[0].split('.')[1]
        initialDate = dividedLine[2]+dividedLine[3]
        # print initialDate 
        datetime.strptime(initialDate, '%Y%m%d%H%M%S').timetuple() 
        unixStamp = mktime(datetime.strptime(initialDate, '%Y%m%d%H%M%S').timetuple())
        # print unixStamp
        dateStamp = time.strftime('%m/%d/%Y %H:%M:%S',time.localtime(unixStamp))
        
        #print dateStamp
        stockPrice = float(dividedLine[4])
        reformatted = unixStamp,dateStamp,stockName,stockPrice
        # print reformatted
    
        if stance == 'none':
            #print stockPrice, previousPrice
            if stockPrice < previousPrice:
    
                print('buy triggered!')
                buyPrice = stockPrice
                print('bought stock for',buyPrice)
                stance = 'holding'
        
                startingTime = unixStamp
        
                if tradeCount == 0:
    
                    startingPrice = buyPrice
                    overallStartingTime = unixStamp
    
                tradeCount += 1
    
        elif stance == 'holding':
            if stockPrice > buyPrice * .002 + buyPrice:
                print('sell triggered!')
                sellPrice = stockPrice
                print('finished trade, sold for:',sellPrice)
                stance = 'none'
                tradeProfit = sellPrice - buyPrice
                totalProfit += tradeProfit
                print(totalProfit)
                endingTime = unixStamp
                timeInvested = endingTime - startingTime
                totalInvestedTime += timeInvested
        
                overallEndingTime = endingTime
        
                tradeCount += 1
    
        previousPrice = stockPrice   # this is a tricky mistake, it should be indented under the main loop
 
      
    print('Trading Complete.')
    print('Profit Per Stock:', totalProfit)
    print('Trade Count:', tradeCount)
    grossPercProf = totalProfit/startingPrice * 100
    print('Gross % Profit:', grossPercProf)
    
    print('How much gross profit did we make off of our',investmentAmount,'investment:')
    grossProf = investmentAmount/startingPrice*totalProfit
    print('we made:', grossProf)
    tradeCommsTotal = tradeComm * tradeCount
    print('amount paid in commissions:',tradeCommsTotal)
    netProf = grossProf-tradeCommsTotal
    print('profit after commissions:',netProf)
    netPercentProf = netProf/investmentAmount * 100
    print('net percent profit after comms:',netPercentProf)
    
    averageInvestedTimeHours = totalInvestedTime/tradeCount/3600
    
    print('average holding length in hours:', averageInvestedTimeHours)
    
    overallTime = overallEndingTime - overallStartingTime
    percentageInvested = totalInvestedTime/overallTime * 100
    
    print('cumulative amount of time holding in days: ',overallTime/86400)
    print('Percentage of the time invested:',percentageInvested)
 
backTest()

print('execution time is: ', time.time() - start_time, " seconds")
print('execution time is %s seconds ' %(time.time() - start_time))
# Out:
# buy triggered!
# bought stock for 11.67
# sell triggered!
# finished trade, sold for: 11.71
# 0.040000000000000924
# buy triggered!
# bought stock for 11.7
# sell triggered!
# finished trade, sold for: 11.725
# 0.06500000000000128
# buy triggered!
# bought stock for 11.72
# sell triggered!
# finished trade, sold for: 11.75
# 0.09500000000000064
# buy triggered!
# bought stock for 11.74
# sell triggered!
# finished trade, sold for: 11.77
# 0.125
# buy triggered!
# bought stock for 11.76
# sell triggered!
# finished trade, sold for: 11.79
# 0.15499999999999936
# buy triggered!
# bought stock for 11.785
# sell triggered!
# finished trade, sold for: 11.81
# 0.17999999999999972
# buy triggered!
# bought stock for 11.805
# sell triggered!
# finished trade, sold for: 11.83
# 0.20500000000000007
# buy triggered!
# bought stock for 11.825
# sell triggered!
# finished trade, sold for: 11.85
# 0.23000000000000043
# buy triggered!
# bought stock for 11.845
# sell triggered!
# finished trade, sold for: 11.87
# 0.254999999999999
# buy triggered!
# bought stock for 11.875
# sell triggered!
# finished trade, sold for: 11.9
# 0.27999999999999936
# buy triggered!
# bought stock for 11.895
# sell triggered!
# finished trade, sold for: 11.92
# 0.3049999999999997
# buy triggered!
# bought stock for 11.915
# sell triggered!
# finished trade, sold for: 11.94
# 0.33000000000000007
# buy triggered!
# bought stock for 11.94
# sell triggered!
# finished trade, sold for: 11.965
# 0.3550000000000004
# buy triggered!
# bought stock for 11.965
# sell triggered!
# finished trade, sold for: 11.99
# 0.3800000000000008
# buy triggered!
# bought stock for 12.005
# sell triggered!
# finished trade, sold for: 12.03
# 0.40499999999999936
# buy triggered!
# bought stock for 12.035
# sell triggered!
# finished trade, sold for: 12.06
# 0.4299999999999997
# buy triggered!
# bought stock for 12.06
# sell triggered!
# finished trade, sold for: 12.09
# 0.4599999999999991
# buy triggered!
# bought stock for 12.08
# sell triggered!
# finished trade, sold for: 12.11
# 0.48999999999999844
# buy triggered!
# bought stock for 12.11
# sell triggered!
# finished trade, sold for: 12.14
# 0.5199999999999996
# buy triggered!
# bought stock for 12.135
# sell triggered!
# finished trade, sold for: 12.16
# 0.5449999999999999
# buy triggered!
# bought stock for 12.175
# sell triggered!
# finished trade, sold for: 12.2
# 0.5699999999999985
# buy triggered!
# bought stock for 12.205
# sell triggered!
# finished trade, sold for: 12.23
# 0.5949999999999989
# buy triggered!
# bought stock for 12.235
# sell triggered!
# finished trade, sold for: 12.26
# 0.6199999999999992
# buy triggered!
# bought stock for 12.275
# sell triggered!
# finished trade, sold for: 12.3
# 0.6449999999999996
# buy triggered!
# bought stock for 12.29
# sell triggered!
# finished trade, sold for: 12.315
# 0.6699999999999999
# buy triggered!
# bought stock for 12.315
# sell triggered!
# finished trade, sold for: 12.34
# 0.6950000000000003
# buy triggered!
# bought stock for 12.345
# sell triggered!
# finished trade, sold for: 12.37
# 0.7199999999999989
# buy triggered!
# bought stock for 12.365
# sell triggered!
# finished trade, sold for: 12.39
# 0.7449999999999992
# buy triggered!
# bought stock for 12.38
# sell triggered!
# finished trade, sold for: 12.41
# 0.7749999999999986
# buy triggered!
# bought stock for 12.445
# sell triggered!
# finished trade, sold for: 12.49
# 0.8199999999999985
# buy triggered!
# bought stock for 12.49
# sell triggered!
# finished trade, sold for: 12.52
# 0.8499999999999979
# buy triggered!
# bought stock for 12.515
# sell triggered!
# finished trade, sold for: 12.55
# 0.884999999999998
# buy triggered!
# bought stock for 12.54
# sell triggered!
# finished trade, sold for: 12.57
# 0.9149999999999991
# buy triggered!
# bought stock for 12.56
# sell triggered!
# finished trade, sold for: 12.59
# 0.9449999999999985
# buy triggered!
# bought stock for 12.58
# sell triggered!
# finished trade, sold for: 12.61
# 0.9749999999999979
# buy triggered!
# bought stock for 12.6
# sell triggered!
# finished trade, sold for: 12.63
# 1.004999999999999
# buy triggered!
# bought stock for 12.62
# sell triggered!
# finished trade, sold for: 12.65
# 1.0350000000000001
# buy triggered!
# bought stock for 12.645
# sell triggered!
# finished trade, sold for: 12.68
# 1.0700000000000003
# buy triggered!
# bought stock for 12.68
# sell triggered!
# finished trade, sold for: 12.71
# 1.1000000000000014
# buy triggered!
# bought stock for 12.72
# sell triggered!
# finished trade, sold for: 12.75
# 1.1300000000000008
# buy triggered!
# bought stock for 12.745
# sell triggered!
# finished trade, sold for: 12.78
# 1.165000000000001
# buy triggered!
# bought stock for 12.79
# sell triggered!
# finished trade, sold for: 12.82
# 1.195000000000002
# buy triggered!
# bought stock for 12.825
# sell triggered!
# finished trade, sold for: 12.86
# 1.2300000000000022
# buy triggered!
# bought stock for 12.865
# sell triggered!
# finished trade, sold for: 12.895
# 1.2600000000000016
# buy triggered!
# bought stock for 12.925
# sell triggered!
# finished trade, sold for: 12.97
# 1.3050000000000015
# buy triggered!
# bought stock for 12.96
# sell triggered!
# finished trade, sold for: 12.99
# 1.3350000000000009
# buy triggered!
# bought stock for 12.98
# sell triggered!
# finished trade, sold for: 13.02
# 1.375
# buy triggered!
# bought stock for 13.02
# sell triggered!
# finished trade, sold for: 13.05
# 1.4050000000000011
# buy triggered!
# bought stock for 13.09
# sell triggered!
# finished trade, sold for: 13.12
# 1.4350000000000005
# buy triggered!
# bought stock for 13.14
# sell triggered!
# finished trade, sold for: 13.17
# 1.4649999999999999
# buy triggered!
# bought stock for 13.165
# sell triggered!
# finished trade, sold for: 13.195
# 1.495000000000001
# buy triggered!
# bought stock for 13.19
# sell triggered!
# finished trade, sold for: 13.22
# 1.5250000000000021
# buy triggered!
# bought stock for 13.215
# sell triggered!
# finished trade, sold for: 13.245
# 1.5550000000000015
# buy triggered!
# bought stock for 13.24
# sell triggered!
# finished trade, sold for: 13.27
# 1.5850000000000009
# buy triggered!
# bought stock for 13.26
# sell triggered!
# finished trade, sold for: 13.29
# 1.6150000000000002
# buy triggered!
# bought stock for 13.285
# sell triggered!
# finished trade, sold for: 13.315
# 1.6449999999999996
# buy triggered!
# bought stock for 13.31
# sell triggered!
# finished trade, sold for: 13.34
# 1.674999999999999
# buy triggered!
# bought stock for 13.345
# sell triggered!
# finished trade, sold for: 13.375
# 1.7049999999999983
# buy triggered!
# bought stock for 13.375
# sell triggered!
# finished trade, sold for: 13.405
# 1.7349999999999977
# buy triggered!
# bought stock for 13.4
# sell triggered!
# finished trade, sold for: 13.43
# 1.764999999999997
# buy triggered!
# bought stock for 13.425
# sell triggered!
# finished trade, sold for: 13.46
# 1.7999999999999972
# buy triggered!
# bought stock for 13.46
# sell triggered!
# finished trade, sold for: 13.49
# 1.8299999999999965
# buy triggered!
# bought stock for 13.48
# sell triggered!
# finished trade, sold for: 13.51
# 1.8599999999999959
# buy triggered!
# bought stock for 13.535
# sell triggered!
# finished trade, sold for: 13.57
# 1.894999999999996
# buy triggered!
# bought stock for 13.58
# sell triggered!
# finished trade, sold for: 13.61
# 1.9249999999999954
# buy triggered!
# bought stock for 13.615
# sell triggered!
# finished trade, sold for: 13.65
# 1.9599999999999955
# buy triggered!
# bought stock for 13.645
# sell triggered!
# finished trade, sold for: 13.68
# 1.9949999999999957
# buy triggered!
# bought stock for 13.675
# sell triggered!
# finished trade, sold for: 13.71
# 2.029999999999996
# buy triggered!
# bought stock for 13.7
# sell triggered!
# finished trade, sold for: 13.73
# 2.059999999999997
# buy triggered!
# bought stock for 13.725
# sell triggered!
# finished trade, sold for: 13.76
# 2.094999999999997
# buy triggered!
# bought stock for 13.77
# sell triggered!
# finished trade, sold for: 13.83
# 2.1549999999999976
# buy triggered!
# bought stock for 13.84
# sell triggered!
# finished trade, sold for: 13.87
# 2.184999999999997
# buy triggered!
# bought stock for 13.86
# sell triggered!
# finished trade, sold for: 13.895
# 2.219999999999997
# buy triggered!
# bought stock for 13.89
# sell triggered!
# finished trade, sold for: 13.92
# 2.2499999999999964
# buy triggered!
# bought stock for 13.92
# sell triggered!
# finished trade, sold for: 13.95
# 2.279999999999996
# buy triggered!
# bought stock for 13.945
# sell triggered!
# finished trade, sold for: 13.98
# 2.314999999999996
# buy triggered!
# bought stock for 13.975
# sell triggered!
# finished trade, sold for: 14.01
# 2.349999999999996
# buy triggered!
# bought stock for 14.005
# sell triggered!
# finished trade, sold for: 14.035
# 2.3799999999999955
# buy triggered!
# bought stock for 14.03
# sell triggered!
# finished trade, sold for: 14.06
# 2.4099999999999966
# buy triggered!
# bought stock for 14.06
# sell triggered!
# finished trade, sold for: 14.09
# 2.439999999999996
# buy triggered!
# bought stock for 14.085
# sell triggered!
# finished trade, sold for: 14.115
# 2.4699999999999953
# buy triggered!
# bought stock for 14.12
# sell triggered!
# finished trade, sold for: 14.15
# 2.4999999999999964
# buy triggered!
# bought stock for 14.155
# sell triggered!
# finished trade, sold for: 14.185
# 2.5299999999999976
# buy triggered!
# bought stock for 14.18
# sell triggered!
# finished trade, sold for: 14.21
# 2.5599999999999987
# buy triggered!
# bought stock for 14.2
# sell triggered!
# finished trade, sold for: 14.23
# 2.59
# buy triggered!
# bought stock for 14.22
# sell triggered!
# finished trade, sold for: 14.25
# 2.619999999999999
# buy triggered!
# bought stock for 14.245
# sell triggered!
# finished trade, sold for: 14.275
# 2.6500000000000004
# buy triggered!
# bought stock for 14.27
# sell triggered!
# finished trade, sold for: 14.3
# 2.6800000000000015
# buy triggered!
# bought stock for 14.3
# sell triggered!
# finished trade, sold for: 14.33
# 2.710000000000001
# buy triggered!
# bought stock for 14.335
# sell triggered!
# finished trade, sold for: 14.365
# 2.74
# buy triggered!
# bought stock for 14.36
# sell triggered!
# finished trade, sold for: 14.39
# 2.7700000000000014
# buy triggered!
# bought stock for 14.41
# sell triggered!
# finished trade, sold for: 14.44
# 2.8000000000000007
# buy triggered!
# bought stock for 14.435
# sell triggered!
# finished trade, sold for: 14.465
# 2.83
# buy triggered!
# bought stock for 14.47
# sell triggered!
# finished trade, sold for: 14.5
# 2.8599999999999994
# buy triggered!
# bought stock for 14.49
# sell triggered!
# finished trade, sold for: 14.52
# 2.889999999999999
# buy triggered!
# bought stock for 14.53
# sell triggered!
# finished trade, sold for: 14.56
# 2.92
# buy triggered!
# bought stock for 14.57
# sell triggered!
# finished trade, sold for: 14.6
# 2.9499999999999993
# buy triggered!
# bought stock for 14.605
# sell triggered!
# finished trade, sold for: 14.635
# 2.9799999999999986
# buy triggered!
# bought stock for 14.63
# sell triggered!
# finished trade, sold for: 14.66
# 3.009999999999998
# buy triggered!
# bought stock for 14.665
# sell triggered!
# finished trade, sold for: 14.695
# 3.039999999999999
# buy triggered!
# bought stock for 14.69
# sell triggered!
# finished trade, sold for: 14.725
# 3.0749999999999993
# buy triggered!
# bought stock for 14.735
# sell triggered!
# finished trade, sold for: 14.765
# 3.1050000000000004
# buy triggered!
# bought stock for 14.76
# sell triggered!
# finished trade, sold for: 14.79
# 3.135
# buy triggered!
# bought stock for 14.785
# sell triggered!
# finished trade, sold for: 14.87
# 3.219999999999999
# buy triggered!
# bought stock for 14.87
# sell triggered!
# finished trade, sold for: 14.9
# 3.25
# buy triggered!
# bought stock for 14.89
# sell triggered!
# finished trade, sold for: 14.92
# 3.2799999999999994
# buy triggered!
# bought stock for 14.91
# sell triggered!
# finished trade, sold for: 14.94
# 3.3099999999999987
# buy triggered!
# bought stock for 14.93
# sell triggered!
# finished trade, sold for: 14.96
# 3.34
# buy triggered!
# bought stock for 14.94
# sell triggered!
# finished trade, sold for: 14.97
# 3.370000000000001
# buy triggered!
# bought stock for 14.97
# sell triggered!
# finished trade, sold for: 15.0
# 3.4000000000000004
# buy triggered!
# bought stock for 15.0
# sell triggered!
# finished trade, sold for: 15.04
# 3.4399999999999995
# buy triggered!
# bought stock for 15.03
# sell triggered!
# finished trade, sold for: 15.07
# 3.4800000000000004
# buy triggered!
# bought stock for 15.065
# sell triggered!
# finished trade, sold for: 15.1
# 3.5150000000000006
# buy triggered!
# bought stock for 15.1
# sell triggered!
# finished trade, sold for: 15.14
# 3.5550000000000015
# buy triggered!
# bought stock for 15.14
# sell triggered!
# finished trade, sold for: 15.18
# 3.5950000000000006
# buy triggered!
# bought stock for 15.17
# Trading Complete.
# Profit Per Stock: 3.5950000000000006
# Trade Count: 231
# Gross % Profit: 30.80548414738647
# How much gross profit did we make off of our 50000 investment:
# we made: 15402.742073693233
# amount paid in commissions: 1617
# profit after commissions: 13785.742073693233
# net percent profit after comms: 27.571484147386467
# average holding length in hours: 12.573804713804714
# cumulative amount of time holding in days:  121.0521875
# Percentage of the time invested: 99.97578141276495
# execution time is:  28.280393838882446  seconds
# execution time is 28.28058624267578 seconds
